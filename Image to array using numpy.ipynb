# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from PIL import Image

# %%
flower=Image.open(r'C:\Users\sankar kona\Downloads\tulip.jpg')

# %%
flower
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1271x736>

# %%
type(flower)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
import numpy as np

# %%
flower=np.asarray(flower)
flower
# Out:
# array([[[183, 165, 155],
#         [183, 165, 155],
#         [183, 165, 155],
#         ...,
#         [183, 170, 162],
#         [181, 168, 160],
#         [177, 164, 156]],
#
#        [[183, 165, 155],
#         [183, 165, 155],
#         [183, 165, 155],
#         ...,
#         [181, 168, 160],
#         [181, 168, 160],
#         [180, 167, 159]],
#
#        [[183, 165, 155],
#         [183, 165, 155],
#         [183, 165, 155],
#         ...,
#         [178, 165, 157],
#         [178, 165, 157],
#         [180, 167, 159]],
#
#        ...,
#
#        [[170, 152, 142],
#         [170, 152, 142],
#         [170, 152, 142],
#         ...,
#         [143, 125, 115],
#         [143, 125, 115],
#         [143, 125, 115]],
#
#        [[169, 151, 141],
#         [169, 151, 141],
#         [169, 151, 141],
#         ...,
#         [141, 123, 113],
#         [141, 123, 113],
#         [141, 123, 113]],
#
#        [[169, 151, 141],
#         [169, 151, 141],
#         [169, 151, 141],
# ...

# %%
type(flower)
# Out:
# numpy.ndarray

# %%
flower.shape
# Out:
# (736, 1271, 3)

# %%
plt.imshow(flower)

# %%
flower_red=flower.copy()

# %%
flower_red
# Out:
# array([[[183, 165, 155],
#         [183, 165, 155],
#         [183, 165, 155],
#         ...,
#         [183, 170, 162],
#         [181, 168, 160],
#         [177, 164, 156]],
#
#        [[183, 165, 155],
#         [183, 165, 155],
#         [183, 165, 155],
#         ...,
#         [181, 168, 160],
#         [181, 168, 160],
#         [180, 167, 159]],
#
#        [[183, 165, 155],
#         [183, 165, 155],
#         [183, 165, 155],
#         ...,
#         [178, 165, 157],
#         [178, 165, 157],
#         [180, 167, 159]],
#
#        ...,
#
#        [[170, 152, 142],
#         [170, 152, 142],
#         [170, 152, 142],
#         ...,
#         [143, 125, 115],
#         [143, 125, 115],
#         [143, 125, 115]],
#
#        [[169, 151, 141],
#         [169, 151, 141],
#         [169, 151, 141],
#         ...,
#         [141, 123, 113],
#         [141, 123, 113],
#         [141, 123, 113]],
#
#        [[169, 151, 141],
#         [169, 151, 141],
#         [169, 151, 141],
# ...

# %%
flower==flower_red
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
# ...

# %%
plt.imshow(flower)

# %%
flower_red.shape
# Out:
# (736, 1271, 3)

# %%
plt.imshow(flower_red[:,:,0])

# %%
flower_red[:,:,0]
# Out:
# array([[183, 183, 183, ..., 183, 181, 177],
#        [183, 183, 183, ..., 181, 181, 180],
#        [183, 183, 183, ..., 178, 178, 180],
#        ...,
#        [170, 170, 170, ..., 143, 143, 143],
#        [169, 169, 169, ..., 141, 141, 141],
#        [169, 169, 169, ..., 141, 141, 141]], dtype=uint8)

# %%
plt.imshow(flower_red[:,:,2],cmap='grey')

# %%
plt.imshow(flower_red[:,:,2],cmap='Blues')

# %%
plt.imshow(flower_red[:,:,1],cmap='PuBu')

# %%
flower_red[:,:,1]
# Out:
# array([[165, 165, 165, ..., 170, 168, 164],
#        [165, 165, 165, ..., 168, 168, 167],
#        [165, 165, 165, ..., 165, 165, 167],
#        ...,
#        [152, 152, 152, ..., 125, 125, 125],
#        [151, 151, 151, ..., 123, 123, 123],
#        [151, 151, 151, ..., 123, 123, 123]], dtype=uint8)
